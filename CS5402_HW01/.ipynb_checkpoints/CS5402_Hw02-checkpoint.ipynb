# %%
######################################################################################################################
# Author: Christopher O'Toole
# Required libraries: seaborn, matplotlib, pandas, numpy, scipy
# Python version: 3.6
######################################################################################################################
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
categorical_attrs = ('Is Home/Away?', 'Is Opponent in AP Top 25 at Preseason?', 'Media', 'Label: Win/Lose')
task5_categorical_attrs = ('Is_Home_or_Away','Is_Opponent_In_AP25_Preseason','Media')
q1_train_df = pd.read_csv('Q1_train_set.csv', dtype={k: 'category' for k in categorical_attrs})
task5_training_set = pd.read_csv('task5_training_set.csv', dtype={k: 'category' for k in task5_categorical_attrs})
task5_training_set.head()
# Out:
#   Is_Home_or_Away Is_Opponent_In_AP25_Preseason  Media Label  Unnamed: 4
# 0            Home                           Out  1-NBC   Win         NaN
# 1            Away                           Out  4-ABC   Win         NaN
# 2            Home                            In  1-NBC   Win         NaN
# 3            Home                           Out  1-NBC   Win         NaN
# 4            Away                            In  4-ABC  Lose         NaN

# %%
q1_train_df['Label: Win/Lose'].value_counts()[0] != q1_train_df.count()[-1]
# Out:
# True

# %%
q1_train_df['Media'].unique()
# Out:
# [1-NBC, 2-ESPN, 3-FOX, 4-ABC]
# Categories (4, object): [1-NBC, 2-ESPN, 3-FOX, 4-ABC]

# %%
from graphviz import Digraph

class TreeNode():
    def __init__(self, partition_df, label):
        self.data = partition_df
        self.label = label
        self.children = []
        self._children_labels = []
        self._split_feature = ''
            
    def partition(self, feature):
        feature_column = self.data[feature]
        children = []
        categories = []
        for category in feature_column.unique():
            children.append(TreeNode(self.data[feature_column == category], self.label))
            categories.append(category)
    
        return children, categories
        
    def split(self, feature):
        self.children, self._children_labels = self.partition(feature)
        self._split_feature = feature
        
    def count(self):
        return self.data.count()[0]
    
    def gain(self, w, children):
        return self.entropy-w.dot(np.array([node.entropy for node in children]))
    
    def gain_ratio(self, w, children):
        return self.gain(w, children)/(-w.dot(np.log2(w)))
    
    def gini(self, w, children):
        return -w.dot(np.array([node.gini for node in children]))
    
    def evaluate_split(self, feature, measure='gain_ratio'):
        children, _ = self.partition(feature)
        w = np.asarray([node.count() for node in children])/self.count()
        return getattr(self, measure)(w, children)

    @property
    def children(self):
        return self._children
    
    @property
    def children_labels(self):
        return self._children_labels
    
    @children.setter
    def children(self, value):
        self._children = value
    
    @property
    def label(self):
        return self._label
    
    @label.setter
    def label(self, value):
        self._label = value
    
    @property
    def data(self):
        return self._data
    
    @data.setter
    def data(self, value):
        self._data = value
    
    @property
    def class_label(self):
        return self.data[self.label].mode()[0]
    
    @property
    def render_label(self):
        label = ''
        
        if self.children:
            label = self._split_feature
        else:
            label = '%s = %s' % (self.label, self.class_label)
            
        return label
    
    @property
    def probabilities(self):
        label_column = self.data[self.label]
        class_counts = label_column.value_counts().values
        p = class_counts/label_column.count()
        p[p == 0] = 1
        return p
    
    @property
    def entropy(self):
        return np.sum(-self.probabilities*np.log2(self.probabilities))
    
    @property
    def gini(self):
        return 1-np.sum(self.probabilities**2)
    
    def __str__(self):
        params = (self.entropy, self.gini)
        return '{Entropy: %.3f, Gini %.3f}' % params
    
class DecisionTree():
    C45_ALGORITHM = 'c4.5'
    ID3_ALGORITHM = 'id3'
    CART_ALGORITHM = 'cart'
    
    def __init__(self, train_df, categorical_attrs=None, algo=C45_ALGORITHM, label=None):
        self.features = list(train_df.columns) if categorical_attrs is None else [c for c in train_df.columns if c in categorical_attrs]
        self.label = label
        self.root = TreeNode(train_df, self.label)
        self.nodes = [self.root]
        self.algo = algo
    
    def fit(self):
        unused_features = {feature:feature for feature in self.features[:-1]}
        nodes = [self.root]
        measures = {
            DecisionTree.ID3_ALGORITHM: 'gain', 
            DecisionTree.C45_ALGORITHM: 'gain_ratio', 
            DecisionTree.CART_ALGORITHM: 'gini'
        }
        
        measure = measures[self.algo.lower()]
        
        while nodes and unused_features:
            node = nodes.pop()
            feature_labels = []
            evaluations = []
            
            for feature in unused_features:
                evaluations.append(node.evaluate_split(feature))
                feature_labels.append(feature)
            
            selected_feature = unused_features[feature_labels[np.asarray(evaluations).argmax()]]
            del unused_features[selected_feature]
            node.split(selected_feature)
            
            for child in node.children:
                if child.data[self.label].value_counts().max() != child.data.count().max():
                    nodes.append(child)
    
    def _predict(self, node, X, y, idxs=None):
        idxs = np.asarray(range(len(X))) if idxs is None else idxs
        
        if not node.children:
            y[idxs] = node.class_label
        else:
            for i, child in enumerate(node.children):
                mask = X[node.render_label] == node.children_labels[i]
                self._predict(child, X[mask], y, idxs=idxs[mask])
        
            
    def predict(self, X):
        y = np.asarray(['']*len(X), dtype=np.object)
        self._predict(self.root, X, y)
        return y
        
                    
    def render(self):
        tree = Digraph('decision_tree', filename='tree.gv')
        nodes = [self.root]
        
        while nodes:
            node = nodes.pop()
            tree.node(str(id(node)), label=node.render_label)
            
            for i, child in enumerate(node.children):
                tree.edge(str(id(node)), str(id(child)), label='%s' % (node.children_labels[i],))
                nodes.append(child)
        
        return tree
            
    @property
    def features(self):
        return self._features
    
    @features.setter
    def features(self, value):
        self._features = value
        
    @property
    def label(self):
        return self._label
    
    @label.setter
    def label(self, value):
        self._label = self.features[-1]
        
    @property
    def root(self):
        return self._root
    
    @root.setter
    def root(self, value):
        self._root = value
        
    @property
    def algo(self):
        return self._algo
    
    @algo.setter
    def algo(self, value):
        self._algo = value

decision_tree = DecisionTree(q1_train_df, categorical_attrs, algo=DecisionTree.CART_ALGORITHM)
decision_tree.fit()
decision_tree.predict(q1_train_df)
# Out:
# array(['Win', 'Lose', 'Win', 'Win', 'Win', 'Win'], dtype=object)

# %%
0.19087450462110933
# Out:
# 0.19087450462110933

# %%
decision_tree.render()
